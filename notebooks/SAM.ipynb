# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from segment_anything import sam_model_registry, SamPredictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 5
#       3 import cv2
#       4 import matplotlib.pyplot as plt
# ----> 5 from segment_anything import sam_model_registry, SamPredictor
#
# ModuleNotFoundError: No module named 'segment_anything'

# %%
import segment_anything
print("Segment Anything Model (SAM) installed successfully!")

# %%
import segment_anything
print("Segment Anything Model (SAM) installed successfully!")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import segment_anything
#       2 print("Segment Anything Model (SAM) installed successfully!")
#
# ModuleNotFoundError: No module named 'segment_anything'

# %%
import torch
import numpy as np
import cv2
import matplotlib.pyplot as plt
from segment_anything import sam_model_registry, SamPredictor

# %%
# Load the model (Choose from 'vit_h', 'vit_l', 'vit_b' based on performance needs)
MODEL_TYPE = "vit_h"  
CHECKPOINT_PATH = "sam_vit_h.pth"  # Download from Meta AI's official repo

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device)
predictor = SamPredictor(sam)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 CHECKPOINT_PATH = "sam_vit_h.pth"  # Download from Meta AI's official repo
#       5 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# ----> 6 sam = sam_model_registry[MODEL_TYPE](checkpoint=CHECKPOINT_PATH).to(device)
#       7 predictor = SamPredictor(sam)
#
# File c:\project_mrsac\mrsac\Lib\site-packages\segment_anything\build_sam.py:15, in build_sam_vit_h(checkpoint)
#      14 def build_sam_vit_h(checkpoint=None):
# ---> 15     return _build_sam(
#      16         encoder_embed_dim=1280,
#      17         encoder_depth=32,
#      18         encoder_num_heads=16,
#      19         encoder_global_attn_indexes=[7, 15, 23, 31],
#      20         checkpoint=checkpoint,
#      21     )
#
# ...
